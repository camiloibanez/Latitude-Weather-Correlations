# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 641

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_df = pd.DataFrame({"City": cities})
weather_df
# Out:
#             City
# 0         lompoc
# 1    pietarsaari
# 2        yeppoon
# 3     ust-omchug
# 4       cururupu
# ..           ...
# 636         okha
# 637         fare
# 638      magadan
# 639     pingshan
# 640         jalu
#
# [641 rows x 1 columns]

# %%
weather_df["Cloudiness"] = ""
weather_df["Country"] = ""
weather_df["Date"] = ""
weather_df["Humidity"] = ""
weather_df["Lat"] = ""
weather_df["Lng"] = ""
weather_df["Max Temp"] = ""
weather_df["Wind Speed"] = ""

weather_df.head()
# Out:
#           City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0       lompoc
# 1  pietarsaari
# 2      yeppoon
# 3   ust-omchug
# 4     cururupu

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


parameters = {"units": units,
             "appid": weather_api_key}

print("Beginning Data Retrieval")
print("-----------------------------")

for index, row in weather_df.iterrows():
    parameters["q"] = row["City"]
    response = requests.get(url, params=parameters).json()
    
    try:        
        weather_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        weather_df.loc[index, "Country"] = response["sys"]["country"]
        weather_df.loc[index, "Date"] = response["dt"]
        weather_df.loc[index, "Humidity"] = response["main"]["humidity"]
        weather_df.loc[index, "Lat"] = response["coord"]["lat"]
        weather_df.loc[index, "Lng"] = response["coord"]["lon"]
        weather_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        weather_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
        
        print(f"Processing Record {index} | {row['City']}")
              
    except (KeyError, IndexError):
              print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 | lompoc
# Processing Record 1 | pietarsaari
# Processing Record 2 | yeppoon
# Processing Record 3 | ust-omchug
# Processing Record 4 | cururupu
# Processing Record 5 | albany
# Processing Record 6 | north bend
# Processing Record 7 | kristiinankaupunki
# Processing Record 8 | nanortalik
# Processing Record 9 | arraial do cabo
# Processing Record 10 | komsomolskiy
# Processing Record 11 | south venice
# Processing Record 12 | hilo
# City not found. Skipping...
# Processing Record 14 | lorengau
# Processing Record 15 | atuona
# Processing Record 16 | olinda
# City not found. Skipping...
# Processing Record 18 | bonavista
# Processing Record 19 | grand gaube
# Processing Record 20 | upernavik
# Processing Record 21 | bluff
# Processing Record 22 | alice springs
# Processing Record 23 | puqi
# Processing Record 24 | puerto ayora
# Processing Record 25 | deputatskiy
# Processing Record 26 | rio gallegos
# Processing Record 27 | vaini
# Processing Record 28 | mar del plata
# Processing Record 29 | khatanga
# Processing Record 30 | narsaq
# Processing Record 31 | storebo
# Processing Record 32 | karasburg
# Processing Record 33 | balakhta
# Processing Record 34 | kodiak
# Processing Record 35 | cape town
# Processing Record 36 | busselton
# Processing Record 37 | mount vernon
# Processing Record 38 | los banos
# Processing Record 39 | saskylakh
# City not found. Skipping...
# Processing Record 41 | kapaa
# Processing Record 42 | rikitea
# Processing Record 43 | mataura
# Processing Record 44 | rinteln
# Processing Record 45 | manyana
# Processing Record 46 | talaya
# Processing Record 47 | tarakan
# Processing Record 48 | panguna
# Processing Record 49 | hithadhoo
# Processing Record 50 | butaritari
# Processing Record 51 | tuatapere
# Processing Record 52 | hermanus
# City not found. Skipping...
# Processing Record 54 | new norfolk
# Processing Record 55 | port lincoln
# Processing Record 56 | east london
# Processing Record 57 | georgetown
# Processing Record 58 | bontang
# Processing Record 59 | dikson
# Processing Record 60 | comodoro rivadavia
# Processing Record 61 | krasyliv
# Processing Record 62 | port alfred
# Processing Record 63 | airai
# Processing Record 64 | ushuaia
# Processing Record 65 | kruisfontein
# Processing Record 66 | suoyarvi
# Processing Record 67 | botro
# Processing Record 68 | palu
# Processing Record 69 | tasiilaq
# Processing Record 70 | jamestown
# Processing Record 71 | lavrentiya
# Processing Record 72 | sao joao da barra
# Processing Record 73 | lokosovo
# Processing Record 74 | tautira
# Processing Record 75 | tuktoyaktuk
# Processing Record 76 | pangai
# Processing Record 77 | port elizabeth
# Processing Record 78 | wajir
# Processing Record 79 | austin
# Processing Record 80 | koupela
# Processing Record 81 | coquimbo
# City not found. Skipping...
# Processing Record 83 | vestmanna
# Processing Record 84 | nikolskoye
# Processing Record 85 | cockburn town
# Processing Record 86 | faanui
# Processing Record 87 | minab
# City not found. Skipping...
# Processing Record 89 | lebu
# Processing Record 90 | tortoli
# City not found. Skipping...
# Processing Record 92 | carnarvon
# Processing Record 93 | pokhara
# City not found. Skipping...
# Processing Record 95 | khandbari
# Processing Record 96 | oistins
# Processing Record 97 | punta arenas
# Processing Record 98 | adrar
# Processing Record 99 | khani
# Processing Record 100 | kaitangata
# Processing Record 101 | vagur
# Processing Record 102 | lagoa
# Processing Record 103 | beloha
# Processing Record 104 | carballo
# Processing Record 105 | union de san antonio
# Processing Record 106 | hobart
# Processing Record 107 | ribeira grande
# Processing Record 108 | yarmouth
# Processing Record 109 | cidreira
# Processing Record 110 | te anau
# Processing Record 111 | tiksi
# Processing Record 112 | barrow
# Processing Record 113 | sept-iles
# Processing Record 114 | galveston
# Processing Record 115 | high level
# Processing Record 116 | umtata
# Processing Record 117 | victoria
# Processing Record 118 | caraquet
# Processing Record 119 | ilulissat
# City not found. Skipping...
# Processing Record 121 | manavalakurichi
# Processing Record 122 | hokitika
# Processing Record 123 | saint anthony
# Processing Record 124 | mujiayingzi
# Processing Record 125 | maldonado
# City not found. Skipping...
# Processing Record 127 | severo-kurilsk
# Processing Record 128 | muroto
# Processing Record 129 | bethel
# Processing Record 130 | cayenne
# Processing Record 131 | leningradskiy
# Processing Record 132 | noumea
# Processing Record 133 | evensk
# Processing Record 134 | bredasdorp
# Processing Record 135 | elizabeth city
# Processing Record 136 | saint-philippe
# Processing Record 137 | kalnibolotskaya
# Processing Record 138 | norman wells
# Processing Record 139 | mormugao
# Processing Record 140 | ketchikan
# Processing Record 141 | lasa
# Processing Record 142 | ponta do sol
# Processing Record 143 | vardo
# Processing Record 144 | hailar
# Processing Record 145 | amos
# Processing Record 146 | tarko-sale
# Processing Record 147 | alyangula
# Processing Record 148 | tigzirt
# City not found. Skipping...
# Processing Record 150 | timra
# Processing Record 151 | atar
# Processing Record 152 | labuhan
# Processing Record 153 | luanda
# Processing Record 154 | bilma
# Processing Record 155 | yellowknife
# City not found. Skipping...
# Processing Record 157 | lakes entrance
# Processing Record 158 | nguru
# Processing Record 159 | rybnoye
# Processing Record 160 | souillac
# Processing Record 161 | katherine
# Processing Record 162 | winsum
# Processing Record 163 | brae
# Processing Record 164 | lata
# City not found. Skipping...
# Processing Record 166 | kutum
# Processing Record 167 | burgeo
# Processing Record 168 | junction city
# Processing Record 169 | monrovia
# Processing Record 170 | launceston
# Processing Record 171 | husavik
# Processing Record 172 | ocos
# Processing Record 173 | lingao
# Processing Record 174 | qaanaaq
# Processing Record 175 | samarinda
# Processing Record 176 | guangyuan
# Processing Record 177 | fortuna
# Processing Record 178 | praia da vitoria
# Processing Record 179 | nome
# Processing Record 180 | waitati
# Processing Record 181 | ambilobe
# Processing Record 182 | vila franca do campo
# City not found. Skipping...
# Processing Record 184 | karratha
# Processing Record 185 | thompson
# Processing Record 186 | santa isabel
# Processing Record 187 | svetlyy
# Processing Record 188 | faya
# Processing Record 189 | namibe
# Processing Record 190 | roma
# Processing Record 191 | iqaluit
# Processing Record 192 | conceicao do araguaia
# Processing Record 193 | sistranda
# Processing Record 194 | san patricio
# Processing Record 195 | solginskiy
# Processing Record 196 | hobyo
# Processing Record 197 | gorontalo
# Processing Record 198 | tessalit
# Processing Record 199 | betanzos
# Processing Record 200 | mahebourg
# Processing Record 201 | henties bay
# Processing Record 202 | vung tau
# Processing Record 203 | gragnano
# Processing Record 204 | geraldton
# Processing Record 205 | belmopan
# Processing Record 206 | nizhneudinsk
# Processing Record 207 | bubaque
# Processing Record 208 | castro
# Processing Record 209 | katsuura
# Processing Record 210 | gasa
# Processing Record 211 | motala
# Processing Record 212 | dharchula
# Processing Record 213 | hurricane
# Processing Record 214 | sabha
# Processing Record 215 | rameswaram
# Processing Record 216 | nouadhibou
# Processing Record 217 | kavieng
# Processing Record 218 | ustka
# Processing Record 219 | belaya gora
# Processing Record 220 | valley
# Processing Record 221 | el higo
# City not found. Skipping...
# Processing Record 223 | zarechnyy
# Processing Record 224 | bodden town
# Processing Record 225 | sao jose do belmonte
# Processing Record 226 | cabo san lucas
# Processing Record 227 | porto torres
# Processing Record 228 | nouakchott
# Processing Record 229 | avarua
# Processing Record 230 | springdale
# Processing Record 231 | watsa
# Processing Record 232 | dali
# Processing Record 233 | muscat
# Processing Record 234 | hamilton
# Processing Record 235 | talnakh
# City not found. Skipping...
# Processing Record 237 | codrington
# Processing Record 238 | sandwick
# Processing Record 239 | lower hutt
# Processing Record 240 | berlevag
# Processing Record 241 | bambous virieux
# Processing Record 242 | kysyl-syr
# Processing Record 243 | pijijiapan
# Processing Record 244 | hualmay
# Processing Record 245 | la libertad
# Processing Record 246 | dejen
# Processing Record 247 | vila velha
# Processing Record 248 | yashkul
# Processing Record 249 | clyde river
# Processing Record 250 | kalevala
# Processing Record 251 | zhovkva
# Processing Record 252 | manama
# Processing Record 253 | khammam
# Processing Record 254 | zabol
# Processing Record 255 | yalutorovsk
# Processing Record 256 | bongaree
# Processing Record 257 | el tocuyo
# Processing Record 258 | pevek
# Processing Record 259 | dubbo
# Processing Record 260 | tucuma
# Processing Record 261 | sao jose da coroa grande
# Processing Record 262 | aberdeen
# City not found. Skipping...
# Processing Record 264 | yulara
# Processing Record 265 | anadyr
# Processing Record 266 | sitka
# Processing Record 267 | kamenka
# Processing Record 268 | altay
# Processing Record 269 | porosozero
# Processing Record 270 | hasaki
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 274 | garowe
# Processing Record 275 | tual
# Processing Record 276 | baie-comeau
# Processing Record 277 | cherskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 280 | saldanha
# Processing Record 281 | sovetskiy
# Processing Record 282 | sciacca
# Processing Record 283 | port hardy
# Processing Record 284 | mount gambier
# Processing Record 285 | rabo de peixe
# Processing Record 286 | pisco
# Processing Record 287 | lewisporte
# City not found. Skipping...
# Processing Record 289 | radomsko
# City not found. Skipping...
# Processing Record 291 | preetz
# Processing Record 292 | novobiryusinskiy
# Processing Record 293 | sambava
# Processing Record 294 | eureka
# Processing Record 295 | malibu
# Processing Record 296 | pietermaritzburg
# Processing Record 297 | zyryanka
# Processing Record 298 | lucapa
# Processing Record 299 | alberton
# Processing Record 300 | batangafo
# Processing Record 301 | ngorongoro
# Processing Record 302 | krasnaya gora
# Processing Record 303 | diu
# Processing Record 304 | itarema
# Processing Record 305 | dudinka
# Processing Record 306 | kendari
# Processing Record 307 | paraiso
# Processing Record 308 | zhuanghe
# Processing Record 309 | sorland
# Processing Record 310 | celestun
# Processing Record 311 | taltal
# Processing Record 312 | torbay
# City not found. Skipping...
# Processing Record 314 | chuy
# Processing Record 315 | provideniya
# Processing Record 316 | yerbogachen
# Processing Record 317 | batemans bay
# Processing Record 318 | mikhaylovka
# Processing Record 319 | qui nhon
# Processing Record 320 | helena
# Processing Record 321 | lisakovsk
# Processing Record 322 | quatre cocos
# City not found. Skipping...
# Processing Record 324 | tanout
# Processing Record 325 | san angelo
# Processing Record 326 | puerto carreno
# Processing Record 327 | griffith
# Processing Record 328 | adre
# Processing Record 329 | kovur
# Processing Record 330 | pombas
# Processing Record 331 | tatawin
# Processing Record 332 | loandjili
# Processing Record 333 | san juan
# Processing Record 334 | alihe
# Processing Record 335 | pilar do sul
# City not found. Skipping...
# Processing Record 337 | bronnoysund
# Processing Record 338 | nizhniy kuranakh
# Processing Record 339 | moerai
# Processing Record 340 | hambantota
# Processing Record 341 | monduli
# Processing Record 342 | broken hill
# Processing Record 343 | laguna
# Processing Record 344 | nykoping
# Processing Record 345 | dogondoutchi
# Processing Record 346 | dese
# City not found. Skipping...
# Processing Record 348 | smithers
# Processing Record 349 | oussouye
# Processing Record 350 | road town
# Processing Record 351 | basco
# Processing Record 352 | los llanos de aridane
# Processing Record 353 | anaconda
# Processing Record 354 | aklavik
# Processing Record 355 | andenes
# Processing Record 356 | lunenburg
# Processing Record 357 | bathsheba
# City not found. Skipping...
# Processing Record 359 | belfast
# Processing Record 360 | bac lieu
# Processing Record 361 | fort smith
# Processing Record 362 | maxixe
# Processing Record 363 | oga
# Processing Record 364 | isangel
# City not found. Skipping...
# Processing Record 366 | weiser
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 369 | lethem
# Processing Record 370 | sorong
# Processing Record 371 | shimoda
# Processing Record 372 | palmer
# Processing Record 373 | namatanai
# City not found. Skipping...
# Processing Record 375 | chulman
# Processing Record 376 | zhireken
# Processing Record 377 | hatfield
# Processing Record 378 | gat
# Processing Record 379 | cap malheureux
# Processing Record 380 | porto novo
# Processing Record 381 | burnie
# Processing Record 382 | san quintin
# Processing Record 383 | sayyan
# Processing Record 384 | wairoa
# Processing Record 385 | the valley
# Processing Record 386 | ambovombe
# Processing Record 387 | abnub
# Processing Record 388 | kloulklubed
# Processing Record 389 | roald
# Processing Record 390 | leh
# Processing Record 391 | bandarbeyla
# Processing Record 392 | makokou
# Processing Record 393 | raudeberg
# Processing Record 394 | adilcevaz
# Processing Record 395 | saint george
# Processing Record 396 | mahajanga
# Processing Record 397 | mehamn
# Processing Record 398 | bairiki
# Processing Record 399 | viedma
# Processing Record 400 | vila do maio
# Processing Record 401 | belen
# Processing Record 402 | markova
# Processing Record 403 | calvinia
# Processing Record 404 | caravelas
# Processing Record 405 | priboj
# Processing Record 406 | fairbanks
# Processing Record 407 | sur
# Processing Record 408 | honiara
# Processing Record 409 | gornyak
# Processing Record 410 | maralal
# Processing Record 411 | port jervis
# Processing Record 412 | misratah
# Processing Record 413 | zyukayka
# Processing Record 414 | saurimo
# Processing Record 415 | kenora
# Processing Record 416 | emet
# Processing Record 417 | zhangjiakou
# Processing Record 418 | ostrovnoy
# Processing Record 419 | nahariyya
# Processing Record 420 | gazli
# Processing Record 421 | olutanga
# Processing Record 422 | solnechnyy
# Processing Record 423 | havoysund
# Processing Record 424 | ginir
# Processing Record 425 | kieta
# City not found. Skipping...
# Processing Record 427 | friedeburg
# Processing Record 428 | fjerritslev
# Processing Record 429 | matamoros
# Processing Record 430 | constitucion
# Processing Record 431 | thunder bay
# Processing Record 432 | laives
# Processing Record 433 | hukuntsi
# Processing Record 434 | hofn
# Processing Record 435 | bengkulu
# Processing Record 436 | morden
# Processing Record 437 | lazaro cardenas
# Processing Record 438 | zhuhai
# Processing Record 439 | marsa matruh
# Processing Record 440 | villanueva de cordoba
# Processing Record 441 | pochutla
# Processing Record 442 | cocoa
# Processing Record 443 | ancud
# Processing Record 444 | billings
# Processing Record 445 | rocha
# Processing Record 446 | tikapur
# Processing Record 447 | omboue
# Processing Record 448 | touros
# Processing Record 449 | ixtapa
# Processing Record 450 | mersing
# Processing Record 451 | ouro preto
# Processing Record 452 | longyearbyen
# Processing Record 453 | saint-francois
# Processing Record 454 | zaigrayevo
# Processing Record 455 | falun
# Processing Record 456 | kaeo
# Processing Record 457 | padang
# Processing Record 458 | urucara
# Processing Record 459 | ulladulla
# Processing Record 460 | yar-sale
# Processing Record 461 | nawa
# Processing Record 462 | mount isa
# Processing Record 463 | vanimo
# Processing Record 464 | praya
# Processing Record 465 | eibar
# Processing Record 466 | lensk
# Processing Record 467 | havre-saint-pierre
# Processing Record 468 | lufilufi
# Processing Record 469 | buala
# Processing Record 470 | verkhoyansk
# Processing Record 471 | salalah
# Processing Record 472 | dunedin
# City not found. Skipping...
# Processing Record 474 | kavaratti
# Processing Record 475 | orel-izumrud
# Processing Record 476 | gerede
# Processing Record 477 | casale monferrato
# Processing Record 478 | tchollire
# Processing Record 479 | banjar
# Processing Record 480 | vestmannaeyjar
# Processing Record 481 | seydi
# Processing Record 482 | lamar
# Processing Record 483 | mareeba
# Processing Record 484 | barcelona
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 487 | fasa
# Processing Record 488 | rosarito
# Processing Record 489 | chokurdakh
# City not found. Skipping...
# Processing Record 491 | riyadh
# Processing Record 492 | ludvika
# Processing Record 493 | tahoua
# Processing Record 494 | zarichne
# Processing Record 495 | honningsvag
# Processing Record 496 | pompeia
# Processing Record 497 | esfarayen
# Processing Record 498 | poum
# Processing Record 499 | mehran
# Processing Record 500 | ituporanga
# Processing Record 501 | northam
# Processing Record 502 | paka
# Processing Record 503 | ejea de los caballeros
# Processing Record 504 | itagiba
# Processing Record 505 | evanston
# Processing Record 506 | zunyi
# Processing Record 507 | taitung
# Processing Record 508 | pangnirtung
# Processing Record 509 | santa cruz
# Processing Record 510 | rio bueno
# Processing Record 511 | camacha
# Processing Record 512 | rio grande
# Processing Record 513 | ndende
# Processing Record 514 | kirakira
# Processing Record 515 | zhigansk
# Processing Record 516 | flinders
# Processing Record 517 | linping
# City not found. Skipping...
# Processing Record 519 | muros
# Processing Record 520 | harsewinkel
# Processing Record 521 | mgachi
# Processing Record 522 | manaus
# Processing Record 523 | assiniboia
# Processing Record 524 | aripuana
# Processing Record 525 | grindavik
# Processing Record 526 | pathein
# Processing Record 527 | bouca
# Processing Record 528 | san marcos
# Processing Record 529 | college
# Processing Record 530 | kenai
# Processing Record 531 | balikpapan
# Processing Record 532 | teguldet
# Processing Record 533 | meulaboh
# Processing Record 534 | grand baie
# Processing Record 535 | loikaw
# Processing Record 536 | iki-burul
# Processing Record 537 | la asuncion
# Processing Record 538 | nemuro
# Processing Record 539 | ballina
# Processing Record 540 | tevaitoa
# Processing Record 541 | umm kaddadah
# Processing Record 542 | san cristobal
# Processing Record 543 | nelson bay
# Processing Record 544 | brewster
# Processing Record 545 | tabuk
# Processing Record 546 | kasungu
# Processing Record 547 | heihe
# Processing Record 548 | selikhino
# Processing Record 549 | inhambane
# Processing Record 550 | emmauss
# Processing Record 551 | esso
# Processing Record 552 | kisangani
# Processing Record 553 | paamiut
# Processing Record 554 | agadez
# Processing Record 555 | bail hongal
# Processing Record 556 | kouango
# Processing Record 557 | putina
# Processing Record 558 | ca mau
# Processing Record 559 | awjilah
# Processing Record 560 | port-gentil
# Processing Record 561 | amahai
# Processing Record 562 | camana
# Processing Record 563 | brokopondo
# Processing Record 564 | mackenzie
# Processing Record 565 | eyl
# Processing Record 566 | nowa sol
# Processing Record 567 | carauari
# Processing Record 568 | wanning
# Processing Record 569 | saint-joseph
# Processing Record 570 | ciudad bolivar
# Processing Record 571 | ahar
# City not found. Skipping...
# Processing Record 573 | queanbeyan
# Processing Record 574 | nautla
# Processing Record 575 | fengkou
# Processing Record 576 | yairipok
# City not found. Skipping...
# Processing Record 578 | talcahuano
# Processing Record 579 | kokstad
# Processing Record 580 | kem
# Processing Record 581 | bambanglipuro
# Processing Record 582 | prado
# Processing Record 583 | la ronge
# Processing Record 584 | vrangel
# Processing Record 585 | twin falls
# Processing Record 586 | magnor
# Processing Record 587 | pinsk
# Processing Record 588 | tiarei
# Processing Record 589 | tigil
# Processing Record 590 | yuzhnyy
# Processing Record 591 | ogre
# Processing Record 592 | quesnel
# Processing Record 593 | vostok
# Processing Record 594 | salinas
# Processing Record 595 | beringovskiy
# Processing Record 596 | banda aceh
# Processing Record 597 | manokwari
# Processing Record 598 | esperance
# Processing Record 599 | cocobeach
# Processing Record 600 | hesla
# Processing Record 601 | saint-augustin
# Processing Record 602 | natal
# Processing Record 603 | nador
# Processing Record 604 | alenquer
# Processing Record 605 | richards bay
# Processing Record 606 | puri
# Processing Record 607 | ledyard
# Processing Record 608 | mnogovershinnyy
# Processing Record 609 | huarmey
# Processing Record 610 | dombas
# City not found. Skipping...
# Processing Record 612 | sao filipe
# Processing Record 613 | kahului
# Processing Record 614 | abha
# Processing Record 615 | minsk
# Processing Record 616 | lianran
# Processing Record 617 | mayumba
# Processing Record 618 | mayor pablo lagerenza
# City not found. Skipping...
# Processing Record 620 | vao
# Processing Record 621 | sajanan
# City not found. Skipping...
# Processing Record 623 | waipawa
# Processing Record 624 | melioratorov
# Processing Record 625 | bani
# Processing Record 626 | semnan
# Processing Record 627 | romans-sur-isere
# Processing Record 628 | chlorakas
# Processing Record 629 | maragogi
# Processing Record 630 | arman
# Processing Record 631 | krasnyy chikoy
# Processing Record 632 | sterling
# Processing Record 633 | solvychegodsk
# Processing Record 634 | mandera
# Processing Record 635 | palana
# Processing Record 636 | okha
# Processing Record 637 | fare
# Processing Record 638 | magadan
# Processing Record 639 | pingshan
# Processing Record 640 | jalu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_df.replace("", "NaN", inplace=True)

weather_df["Cloudiness"] = weather_df["Cloudiness"].astype(float)
weather_df["Date"] = weather_df["Date"].astype(float)
weather_df["Humidity"] = weather_df["Humidity"].astype(float)
weather_df["Lat"] = weather_df["Lat"].astype(float)
weather_df["Lng"] = weather_df["Lng"].astype(float)
weather_df["Max Temp"] = weather_df["Max Temp"].astype(float)
weather_df["Wind Speed"] = weather_df["Wind Speed"].astype(float)

weather_df.dropna(inplace=True)

weather_df["Cloudiness"] = weather_df["Cloudiness"].astype(int)
weather_df["Humidity"] = weather_df["Humidity"].astype(int)

weather_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.count()
# Out:
# City          597
# Cloudiness    597
# Country       597
# Date          597
# Humidity      597
# Lat           597
# Lng           597
# Max Temp      597
# Wind Speed    597
# dtype: int64

# %%
weather_df.to_csv("Cities.csv")
weather_df.head()
# Out:
#           City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0       lompoc           0      US  1.586046e+09        59  34.64 -120.46
# 1  pietarsaari          19      FI  1.586046e+09        50  63.65   22.68
# 2      yeppoon          40      AU  1.586046e+09        74 -23.13  150.73
# 3   ust-omchug          91      RU  1.586046e+09        84  61.15  149.63
# 4     cururupu          93      BR  1.586046e+09        91  -1.83  -44.87
#
#    Max Temp  Wind Speed
# 0     66.00       12.75
# 1     30.20       10.29
# 2     78.80        6.93
# 3     13.41        7.23
# 4     78.17        5.70

# %%
date = weather_df.loc[0, ["Date"]]
date2 = time.gmtime(date)
# print(date2)
date3 = f"({date2[1]}/{date2[2]}/{date2[0]})"
# print(date3)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Max Temp", title = f"City Latitude vs. Max Temperature {date3}",
                edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.tight_layout()

plt.savefig("fig1.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Humidity", title=f"City Latitude vs. Humidity {date3}",
               edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.tight_layout()

plt.savefig("fig2.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
