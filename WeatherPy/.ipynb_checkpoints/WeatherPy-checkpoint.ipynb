# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime as dt
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 641

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_df = pd.DataFrame({"City": cities})
weather_df
# Out:
#                City
# 0          hermanus
# 1         busselton
# 2            hobart
# 3          thompson
# 4             vaini
# ..              ...
# 636  augusto correa
# 637         tucurui
# 638          shache
# 639      tolaga bay
# 640             soe
#
# [641 rows x 1 columns]

# %%
weather_df["Cloudiness"] = ""
weather_df["Country"] = ""
weather_df["Date"] = ""
weather_df["Humidity"] = ""
weather_df["Lat"] = ""
weather_df["Lng"] = ""
weather_df["Max Temp"] = ""
weather_df["Wind Speed"] = ""

weather_df.head()
# Out:
#         City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0   hermanus
# 1  busselton
# 2     hobart
# 3   thompson
# 4      vaini

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


parameters = {"units": units,
             "appid": weather_api_key}

print("Beginning Data Retrieval")
print("-----------------------------")

for index, row in weather_df.iterrows():
    parameters["q"] = row["City"]
    response = requests.get(url, params=parameters).json()
    
    try:        
        weather_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        weather_df.loc[index, "Country"] = response["sys"]["country"]
        weather_df.loc[index, "Date"] = response["dt"]
        weather_df.loc[index, "Humidity"] = response["main"]["humidity"]
        weather_df.loc[index, "Lat"] = response["coord"]["lat"]
        weather_df.loc[index, "Lng"] = response["coord"]["lon"]
        weather_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        weather_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
        
        print(f"Processing Record {index} | {row['City']}")
              
    except (KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 | hermanus
# Processing Record 1 | busselton
# Processing Record 2 | hobart
# Processing Record 3 | thompson
# Processing Record 4 | vaini
# Processing Record 5 | albany
# Processing Record 6 | bluff
# Processing Record 7 | mataura
# City not found. Skipping...
# Processing Record 9 | rikitea
# City not found. Skipping...
# Processing Record 11 | beitbridge
# Processing Record 12 | nikolskoye
# Processing Record 13 | tuatapere
# Processing Record 14 | ankazoabo
# Processing Record 15 | narsaq
# Processing Record 16 | katsuura
# Processing Record 17 | san prisco
# Processing Record 18 | lompoc
# Processing Record 19 | omboue
# City not found. Skipping...
# Processing Record 21 | yellowknife
# Processing Record 22 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 24 | butaritari
# Processing Record 25 | barentu
# Processing Record 26 | punta arenas
# Processing Record 27 | sciacca
# Processing Record 28 | hilo
# Processing Record 29 | ancud
# City not found. Skipping...
# Processing Record 31 | port hardy
# Processing Record 32 | jamestown
# Processing Record 33 | ayan
# Processing Record 34 | port alfred
# Processing Record 35 | seymchan
# Processing Record 36 | solnechnyy
# Processing Record 37 | sao filipe
# Processing Record 38 | east london
# Processing Record 39 | cape town
# Processing Record 40 | birao
# Processing Record 41 | maudaha
# Processing Record 42 | port hedland
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 | saint-louis
# Processing Record 46 | mahebourg
# City not found. Skipping...
# Processing Record 48 | asau
# Processing Record 49 | ushuaia
# Processing Record 50 | severo-kurilsk
# Processing Record 51 | matamoros
# Processing Record 52 | ketchikan
# City not found. Skipping...
# Processing Record 54 | ostrovnoy
# Processing Record 55 | gat
# Processing Record 56 | dikson
# Processing Record 57 | provideniya
# Processing Record 58 | acapulco
# Processing Record 59 | niamey
# Processing Record 60 | ribeira grande
# Processing Record 61 | flin flon
# Processing Record 62 | bandarbeyla
# Processing Record 63 | lorengau
# Processing Record 64 | ambon
# Processing Record 65 | storsteinnes
# Processing Record 66 | victoria
# Processing Record 67 | cockburn town
# Processing Record 68 | georgetown
# Processing Record 69 | carnarvon
# Processing Record 70 | haines junction
# City not found. Skipping...
# Processing Record 72 | praia
# Processing Record 73 | brae
# Processing Record 74 | hithadhoo
# Processing Record 75 | belaya gora
# Processing Record 76 | dwarka
# Processing Record 77 | hargeysa
# City not found. Skipping...
# Processing Record 79 | kapaa
# Processing Record 80 | new norfolk
# Processing Record 81 | linhares
# Processing Record 82 | ust-maya
# Processing Record 83 | mar del plata
# Processing Record 84 | port elizabeth
# Processing Record 85 | tobermory
# Processing Record 86 | tiksi
# Processing Record 87 | esso
# Processing Record 88 | kargasok
# Processing Record 89 | manado
# Processing Record 90 | havelock
# Processing Record 91 | eloy
# Processing Record 92 | casablanca
# Processing Record 93 | nouadhibou
# Processing Record 94 | teguldet
# Processing Record 95 | san francisco
# Processing Record 96 | traverse city
# Processing Record 97 | besancon
# Processing Record 98 | mezen
# Processing Record 99 | alofi
# Processing Record 100 | manta
# Processing Record 101 | nanortalik
# Processing Record 102 | tasiilaq
# Processing Record 103 | barrow
# Processing Record 104 | bredasdorp
# Processing Record 105 | havoysund
# Processing Record 106 | leningradskiy
# Processing Record 107 | abu samrah
# Processing Record 108 | susehri
# Processing Record 109 | kirs
# Processing Record 110 | nago
# Processing Record 111 | puerto ayora
# Processing Record 112 | salinopolis
# Processing Record 113 | atuona
# Processing Record 114 | sao bento do sul
# Processing Record 115 | ponta do sol
# Processing Record 116 | carutapera
# Processing Record 117 | saurimo
# Processing Record 118 | spartanburg
# Processing Record 119 | naze
# Processing Record 120 | bereda
# Processing Record 121 | hay river
# Processing Record 122 | rocha
# Processing Record 123 | barreirinha
# Processing Record 124 | mocuba
# Processing Record 125 | komsomolskiy
# Processing Record 126 | asyut
# Processing Record 127 | aklavik
# Processing Record 128 | guerrero negro
# Processing Record 129 | abu dhabi
# Processing Record 130 | kahului
# Processing Record 131 | saint-philippe
# Processing Record 132 | banda aceh
# Processing Record 133 | nuqui
# Processing Record 134 | upernavik
# Processing Record 135 | vasto
# Processing Record 136 | ibiapina
# Processing Record 137 | yulara
# Processing Record 138 | imeni poliny osipenko
# Processing Record 139 | cabo san lucas
# Processing Record 140 | verkhoyansk
# Processing Record 141 | verkhnevilyuysk
# Processing Record 142 | san carlos de bariloche
# Processing Record 143 | kidal
# Processing Record 144 | tabuk
# Processing Record 145 | loviisa
# Processing Record 146 | saint george
# Processing Record 147 | itarema
# Processing Record 148 | avarua
# Processing Record 149 | loubomo
# Processing Record 150 | grand gaube
# Processing Record 151 | vaxjo
# Processing Record 152 | vallenar
# City not found. Skipping...
# Processing Record 154 | eureka
# Processing Record 155 | san cristobal
# Processing Record 156 | lazaro cardenas
# Processing Record 157 | pangnirtung
# Processing Record 158 | clyde river
# Processing Record 159 | hualmay
# Processing Record 160 | fortuna
# Processing Record 161 | salalah
# Processing Record 162 | malinovskiy
# City not found. Skipping...
# Processing Record 164 | khandyga
# Processing Record 165 | saint-francois
# Processing Record 166 | kuytun
# Processing Record 167 | jurm
# Processing Record 168 | hobyo
# Processing Record 169 | winnemucca
# Processing Record 170 | traian
# Processing Record 171 | jamsa
# City not found. Skipping...
# Processing Record 173 | spearfish
# Processing Record 174 | qaqortoq
# Processing Record 175 | thinadhoo
# Processing Record 176 | karak
# Processing Record 177 | kodiak
# Processing Record 178 | qaanaaq
# Processing Record 179 | noumea
# Processing Record 180 | belyy yar
# Processing Record 181 | ishigaki
# Processing Record 182 | grindavik
# Processing Record 183 | payakumbuh
# City not found. Skipping...
# Processing Record 185 | pouembout
# City not found. Skipping...
# Processing Record 187 | luganville
# Processing Record 188 | poum
# Processing Record 189 | mokhsogollokh
# Processing Record 190 | hamilton
# City not found. Skipping...
# Processing Record 192 | san giorgio del sannio
# Processing Record 193 | saint-pierre
# Processing Record 194 | ferme-neuve
# City not found. Skipping...
# Processing Record 196 | castro
# Processing Record 197 | mahibadhoo
# Processing Record 198 | cherskiy
# Processing Record 199 | arraial do cabo
# Processing Record 200 | awbari
# Processing Record 201 | norman wells
# Processing Record 202 | saskylakh
# Processing Record 203 | hofn
# City not found. Skipping...
# Processing Record 205 | conakry
# Processing Record 206 | kenora
# Processing Record 207 | shalakusha
# Processing Record 208 | valdivia
# Processing Record 209 | san patricio
# City not found. Skipping...
# Processing Record 211 | kushalgarh
# City not found. Skipping...
# Processing Record 213 | finsterwalde
# Processing Record 214 | bambous virieux
# Processing Record 215 | akyab
# Processing Record 216 | samoded
# Processing Record 217 | bugiri
# Processing Record 218 | half moon bay
# Processing Record 219 | tantoyuca
# Processing Record 220 | aykhal
# Processing Record 221 | lebu
# Processing Record 222 | kaitangata
# Processing Record 223 | balakhta
# Processing Record 224 | arinos
# Processing Record 225 | saldanha
# Processing Record 226 | buala
# City not found. Skipping...
# Processing Record 228 | coolum beach
# Processing Record 229 | griffith
# Processing Record 230 | manoharpur
# Processing Record 231 | kavieng
# Processing Record 232 | kasongo-lunda
# Processing Record 233 | manjacaze
# Processing Record 234 | turbat
# Processing Record 235 | bathsheba
# Processing Record 236 | fort collins
# Processing Record 237 | kyela
# Processing Record 238 | esperance
# Processing Record 239 | high prairie
# Processing Record 240 | kununurra
# City not found. Skipping...
# Processing Record 242 | teya
# Processing Record 243 | sicamous
# Processing Record 244 | iskateley
# Processing Record 245 | senanga
# Processing Record 246 | almaty
# Processing Record 247 | borzya
# Processing Record 248 | malatya
# Processing Record 249 | talcahuano
# Processing Record 250 | airai
# Processing Record 251 | seoul
# Processing Record 252 | hof
# Processing Record 253 | kruisfontein
# Processing Record 254 | girvan
# Processing Record 255 | barra do corda
# Processing Record 256 | gari
# Processing Record 257 | marsh harbour
# Processing Record 258 | nome
# Processing Record 259 | kouvola
# Processing Record 260 | el real de santa maria
# Processing Record 261 | saint-gabriel
# Processing Record 262 | gamba
# Processing Record 263 | yumen
# Processing Record 264 | pevek
# Processing Record 265 | leshukonskoye
# Processing Record 266 | chokurdakh
# Processing Record 267 | kozhevnikovo
# Processing Record 268 | birjand
# Processing Record 269 | grafton
# Processing Record 270 | jalu
# Processing Record 271 | rio grande
# Processing Record 272 | sistranda
# Processing Record 273 | lensk
# Processing Record 274 | baoro
# Processing Record 275 | flinders
# Processing Record 276 | bilibino
# Processing Record 277 | pemba
# City not found. Skipping...
# Processing Record 279 | sakakah
# Processing Record 280 | longyearbyen
# Processing Record 281 | codrington
# Processing Record 282 | sakaraha
# Processing Record 283 | pareora
# Processing Record 284 | urengoy
# Processing Record 285 | puerto madryn
# City not found. Skipping...
# Processing Record 287 | alcudia
# City not found. Skipping...
# Processing Record 289 | iralaya
# Processing Record 290 | bonavista
# Processing Record 291 | shadegan
# Processing Record 292 | simao
# City not found. Skipping...
# Processing Record 294 | sisimiut
# Processing Record 295 | tigil
# Processing Record 296 | zhigansk
# Processing Record 297 | chuy
# Processing Record 298 | teupasenti
# Processing Record 299 | khatanga
# Processing Record 300 | paka
# Processing Record 301 | dera bugti
# Processing Record 302 | klaksvik
# Processing Record 303 | geraldton
# Processing Record 304 | vernon
# Processing Record 305 | waingapu
# Processing Record 306 | plouzane
# Processing Record 307 | bethel
# Processing Record 308 | kiunga
# Processing Record 309 | bluefields
# Processing Record 310 | piranhas
# Processing Record 311 | vuktyl
# Processing Record 312 | uvat
# City not found. Skipping...
# Processing Record 314 | almenara
# Processing Record 315 | berlevag
# Processing Record 316 | pacific grove
# Processing Record 317 | nenjiang
# Processing Record 318 | the valley
# Processing Record 319 | kamenka
# Processing Record 320 | governador dix-sept rosado
# Processing Record 321 | iracoubo
# Processing Record 322 | viedma
# Processing Record 323 | lukulu
# Processing Record 324 | tank
# Processing Record 325 | sambava
# City not found. Skipping...
# Processing Record 327 | ixtapa
# Processing Record 328 | porto belo
# Processing Record 329 | lasa
# Processing Record 330 | luderitz
# Processing Record 331 | ust-tsilma
# Processing Record 332 | llanelli
# Processing Record 333 | murray bridge
# Processing Record 334 | jacksonville
# Processing Record 335 | prieska
# City not found. Skipping...
# Processing Record 337 | kuybyshevskiy zaton
# Processing Record 338 | samfya
# Processing Record 339 | taltal
# Processing Record 340 | ajuchitlan
# Processing Record 341 | sinnamary
# Processing Record 342 | oranjestad
# City not found. Skipping...
# Processing Record 344 | iqaluit
# Processing Record 345 | bambanglipuro
# Processing Record 346 | bubaque
# Processing Record 347 | trelew
# Processing Record 348 | tateyama
# Processing Record 349 | syracuse
# Processing Record 350 | surskoye
# Processing Record 351 | bac lieu
# Processing Record 352 | fairbanks
# Processing Record 353 | ashcroft
# Processing Record 354 | forestville
# Processing Record 355 | merauke
# Processing Record 356 | souillac
# Processing Record 357 | mbinga
# Processing Record 358 | nizhniy kuranakh
# Processing Record 359 | skjervoy
# Processing Record 360 | derzhavinsk
# City not found. Skipping...
# Processing Record 362 | lokosovo
# Processing Record 363 | oriximina
# Processing Record 364 | baykit
# Processing Record 365 | byron bay
# Processing Record 366 | faanui
# City not found. Skipping...
# Processing Record 368 | iquique
# Processing Record 369 | bilma
# Processing Record 370 | mareeba
# Processing Record 371 | meulaboh
# Processing Record 372 | sarlat-la-caneda
# Processing Record 373 | meadow lake
# City not found. Skipping...
# Processing Record 375 | naryan-mar
# Processing Record 376 | elizabeth city
# Processing Record 377 | faya
# City not found. Skipping...
# Processing Record 379 | honningsvag
# Processing Record 380 | ust-kan
# Processing Record 381 | torbay
# Processing Record 382 | barinas
# Processing Record 383 | inuvik
# Processing Record 384 | pisco
# Processing Record 385 | te anau
# Processing Record 386 | eyl
# Processing Record 387 | bengkulu
# Processing Record 388 | coahuayana
# Processing Record 389 | chernyakhiv
# Processing Record 390 | touros
# Processing Record 391 | santa rosa
# City not found. Skipping...
# Processing Record 393 | kijang
# Processing Record 394 | labuhan
# Processing Record 395 | tucuma
# Processing Record 396 | verkhnyaya inta
# Processing Record 397 | paeroa
# Processing Record 398 | natchitoches
# City not found. Skipping...
# Processing Record 400 | puerto escondido
# Processing Record 401 | baoqing
# Processing Record 402 | west fargo
# Processing Record 403 | poddorye
# Processing Record 404 | quelimane
# Processing Record 405 | southbridge
# Processing Record 406 | coihaique
# Processing Record 407 | canico
# Processing Record 408 | palaia fokaia
# Processing Record 409 | kumphawapi
# City not found. Skipping...
# Processing Record 411 | choix
# Processing Record 412 | xichang
# Processing Record 413 | sao felix do xingu
# Processing Record 414 | siocon
# Processing Record 415 | fayaoue
# Processing Record 416 | lagoa
# Processing Record 417 | korla
# Processing Record 418 | constitucion
# Processing Record 419 | vestmannaeyjar
# Processing Record 420 | lubao
# Processing Record 421 | emerald
# Processing Record 422 | kuito
# Processing Record 423 | colares
# Processing Record 424 | ahuimanu
# Processing Record 425 | kenai
# Processing Record 426 | jacqueville
# Processing Record 427 | jinji
# Processing Record 428 | barmer
# Processing Record 429 | santana
# Processing Record 430 | hasaki
# Processing Record 431 | pilar
# Processing Record 432 | port lincoln
# Processing Record 433 | mogocha
# Processing Record 434 | nara
# Processing Record 435 | dingle
# Processing Record 436 | chapais
# Processing Record 437 | melilla
# Processing Record 438 | stephenville
# Processing Record 439 | la primavera
# Processing Record 440 | vilyuysk
# Processing Record 441 | dundee
# Processing Record 442 | harper
# Processing Record 443 | husavik
# Processing Record 444 | nguruka
# City not found. Skipping...
# Processing Record 446 | cidreira
# Processing Record 447 | kawalu
# Processing Record 448 | basoko
# Processing Record 449 | kyshtovka
# Processing Record 450 | caravelas
# City not found. Skipping...
# Processing Record 452 | boa vista
# Processing Record 453 | rancho palos verdes
# Processing Record 454 | kibuye
# Processing Record 455 | ihosy
# Processing Record 456 | ambunti
# Processing Record 457 | oda
# Processing Record 458 | taoudenni
# Processing Record 459 | ecoporanga
# Processing Record 460 | camabatela
# Processing Record 461 | mirnyy
# Processing Record 462 | hambantota
# City not found. Skipping...
# Processing Record 464 | san antonio
# Processing Record 465 | remontnoye
# Processing Record 466 | mangai
# Processing Record 467 | ucluelet
# Processing Record 468 | soledade
# Processing Record 469 | bayevo
# Processing Record 470 | ilulissat
# Processing Record 471 | boyolangu
# Processing Record 472 | presidencia roque saenz pena
# Processing Record 473 | mlyniv
# Processing Record 474 | college
# Processing Record 475 | richards bay
# Processing Record 476 | along
# Processing Record 477 | dancheng
# City not found. Skipping...
# Processing Record 479 | nacala
# Processing Record 480 | vanimo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 483 | srednekolymsk
# Processing Record 484 | orotina
# Processing Record 485 | ixtlan del rio
# Processing Record 486 | nicoya
# Processing Record 487 | kaoma
# Processing Record 488 | dvinskoy
# City not found. Skipping...
# Processing Record 490 | sungaipenuh
# Processing Record 491 | coruripe
# Processing Record 492 | muros
# Processing Record 493 | gambela
# Processing Record 494 | kurayoshi
# Processing Record 495 | okhotsk
# Processing Record 496 | sioux lookout
# Processing Record 497 | krasnoselkup
# Processing Record 498 | evensk
# Processing Record 499 | broken hill
# Processing Record 500 | riyadh
# Processing Record 501 | esil
# Processing Record 502 | dongsheng
# Processing Record 503 | santa rosalia
# Processing Record 504 | izhevskoye
# Processing Record 505 | lavrentiya
# Processing Record 506 | rafai
# Processing Record 507 | palmer
# Processing Record 508 | houma
# Processing Record 509 | antofagasta
# Processing Record 510 | coquimbo
# Processing Record 511 | quincy
# City not found. Skipping...
# Processing Record 513 | manono
# Processing Record 514 | cabedelo
# Processing Record 515 | ulety
# Processing Record 516 | mount gambier
# Processing Record 517 | orocue
# Processing Record 518 | north platte
# Processing Record 519 | puerto leguizamo
# Processing Record 520 | lichuan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 523 | atar
# Processing Record 524 | tabou
# Processing Record 525 | melivoia
# Processing Record 526 | yingkou
# Processing Record 527 | vardo
# Processing Record 528 | mubi
# Processing Record 529 | tiarei
# Processing Record 530 | poirino
# Processing Record 531 | saint anthony
# Processing Record 532 | liverpool
# Processing Record 533 | gatbo
# Processing Record 534 | miajadas
# Processing Record 535 | cayenne
# Processing Record 536 | cantaura
# Processing Record 537 | messina
# Processing Record 538 | rockhampton
# Processing Record 539 | argentan
# Processing Record 540 | sainte-suzanne
# Processing Record 541 | olafsvik
# Processing Record 542 | mogadishu
# Processing Record 543 | lara
# City not found. Skipping...
# Processing Record 545 | paamiut
# Processing Record 546 | adrar
# Processing Record 547 | buzmeyin
# Processing Record 548 | deputatskiy
# Processing Record 549 | cham
# City not found. Skipping...
# Processing Record 551 | raudeberg
# Processing Record 552 | pflugerville
# Processing Record 553 | jaque
# Processing Record 554 | west lorne
# Processing Record 555 | namwala
# Processing Record 556 | talavera de la reina
# Processing Record 557 | nueva rosita
# Processing Record 558 | cambridge
# Processing Record 559 | pringsewu
# Processing Record 560 | bangassou
# Processing Record 561 | amurzet
# Processing Record 562 | inhambane
# Processing Record 563 | khash
# Processing Record 564 | itoman
# Processing Record 565 | corum
# Processing Record 566 | bayji
# Processing Record 567 | kloulklubed
# Processing Record 568 | campo de criptana
# Processing Record 569 | zheleznodorozhnyy
# Processing Record 570 | la peca
# Processing Record 571 | izhma
# Processing Record 572 | warrnambool
# Processing Record 573 | kishi
# Processing Record 574 | baruun-urt
# Processing Record 575 | baneasa
# Processing Record 576 | slonim
# Processing Record 577 | payo
# Processing Record 578 | tanabe
# Processing Record 579 | conceicao do araguaia
# Processing Record 580 | vila franca do campo
# Processing Record 581 | balkhash
# Processing Record 582 | richmond
# Processing Record 583 | worcester
# Processing Record 584 | nikolayevsk-na-amure
# Processing Record 585 | barcelona
# Processing Record 586 | qandala
# Processing Record 587 | arlit
# Processing Record 588 | borogontsy
# Processing Record 589 | ajdabiya
# Processing Record 590 | rawson
# Processing Record 591 | shimsk
# Processing Record 592 | gazojak
# Processing Record 593 | vao
# Processing Record 594 | olimpia
# Processing Record 595 | batagay-alyta
# City not found. Skipping...
# Processing Record 597 | quesnel
# Processing Record 598 | padang
# City not found. Skipping...
# Processing Record 600 | birzai
# Processing Record 601 | hampden
# Processing Record 602 | mancio lima
# Processing Record 603 | valparaiso
# Processing Record 604 | cabatuan
# Processing Record 605 | canalete
# Processing Record 606 | alice springs
# Processing Record 607 | preobrazheniye
# Processing Record 608 | sorland
# Processing Record 609 | goose creek
# Processing Record 610 | loandjili
# Processing Record 611 | langenthal
# Processing Record 612 | kudahuvadhoo
# Processing Record 613 | suhbaatar
# Processing Record 614 | kita
# Processing Record 615 | quatre cocos
# Processing Record 616 | ahipara
# Processing Record 617 | kang
# Processing Record 618 | fairview
# Processing Record 619 | lobatse
# Processing Record 620 | aksha
# Processing Record 621 | alugan
# Processing Record 622 | les cayes
# Processing Record 623 | vanavara
# Processing Record 624 | safaga
# Processing Record 625 | gunjur
# Processing Record 626 | tashara
# Processing Record 627 | bardiyah
# Processing Record 628 | beloha
# City not found. Skipping...
# Processing Record 630 | puro
# Processing Record 631 | gao
# Processing Record 632 | dunedin
# Processing Record 633 | altay
# Processing Record 634 | khorinsk
# City not found. Skipping...
# Processing Record 636 | augusto correa
# Processing Record 637 | tucurui
# Processing Record 638 | shache
# Processing Record 639 | tolaga bay
# Processing Record 640 | soe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_df.replace("", "NaN", inplace=True)

weather_df["Date"] = weather_df["Date"].astype(float)
weather_df["Lat"] = weather_df["Lat"].astype(float)
weather_df["Lng"] = weather_df["Lng"].astype(float)
weather_df["Max Temp"] = weather_df["Max Temp"].astype(float)
weather_df["Wind Speed"] = weather_df["Wind Speed"].astype(float)

weather_df.dropna(inplace=True)

weather_df["Cloudiness"] = weather_df["Cloudiness"].astype(int)
weather_df["Humidity"] = weather_df["Humidity"].astype(int)

weather_df.reset_index(drop=True, inplace=True)

weather_df.index.name = "City_ID"

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.count()
# Out:
# City          587
# Cloudiness    587
# Country       587
# Date          587
# Humidity      587
# Lat           587
# Lng           587
# Max Temp      587
# Wind Speed    587
# dtype: int64

# %%
weather_df.to_csv("Cities.csv")
weather_df.head()
# Out:
#               City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# City_ID
# 0         hermanus         100      ZA  1.599841e+09        83 -34.42   19.23
# 1        busselton           0      AU  1.599841e+09        74 -33.65  115.33
# 2           hobart         100      AU  1.599841e+09        95 -42.88  147.33
# 3         thompson         100      CA  1.599841e+09        95  55.74  -97.86
# 4            vaini           1      TO  1.599841e+09        74 -21.20 -175.20
#
#          Max Temp  Wind Speed
# City_ID
# 0           62.01        8.99
# 1           45.00        4.34
# 2           48.99        5.10
# 3           43.32       10.71
# 4           71.11       11.39

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
date = weather_df.loc[0, ["Date"]]
date = dt.datetime.fromtimestamp(date)
date_string = date.strftime("%m/%d/%Y")
date_string
# Out:
# '09/11/2020'

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Max Temp", title = f"City Latitude vs. Max Temperature {date_string}",
                edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.tight_layout()

plt.savefig("fig1.png")

# %% [markdown]
# Here the maximum temperature of cities plotted against their latitude. The trend shows that max temperatures decrease the farther from the equator the city is.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Humidity", title=f"City Latitude vs. Humidity {date_string}",
               edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.tight_layout()

plt.savefig("fig2.png")

# %% [markdown]
# Here the humidity of cities is plotted against their latitude. There doesn't seem to be a strong trend between humidity and latitude.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Cloudiness", title=f"City Latitude vs. Cloudiness {date_string}",
               edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.tight_layout()

plt.savefig("fig3.png")

# %% [markdown]
# Here the cloudiness of cities plotted against their latitude. There seems to be horizontal lines along the easily divisible numbers weathermen like to forecast data on.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_df.plot(kind="scatter", x="Lat", y="Wind Speed", title=f"City Latitude vs. Wind Speed {date_string}",
               edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.tight_layout()

plt.savefig("fig4.png")

# %% [markdown]
# Here the wind speed of cities is plotted against their latitude. It appears that higher wind speeds occur farther from the equator.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_hemisphere = weather_df.loc[weather_df["Lat"] >= 0,:]
Southern_hemisphere = weather_df.loc[weather_df["Lat"] < 0,:]

# %%
# OPTIONAL: Create a function to create Linear Regression plots
hemispheres = [Northern_hemisphere, Southern_hemisphere]

for hemisphere in hemispheres:
    conditions = ["Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
    for condition in conditions:
        hemisphere.plot(kind="scatter", x="Lat", y=f"{condition}", title = f"City Latitude vs. {condition} {date_string}",
                edgecolor="black", s=40, alpha=0.75)
        plt.xlabel("Latitude")
        plt.ylabel(f"{condition}")
        plt.grid()
        plt.tight_layout()

        (slope, intercept, rvalue, pvalue, stderr) = linregress(hemisphere["Lat"], hemisphere[f"{condition}"])
        regress_values = hemisphere["Lat"]*slope + intercept
        line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
        plt.plot(hemisphere["Lat"], regress_values, "r-")
        if hemisphere.iloc[0,0] == Northern_hemisphere.iloc[0,0]:
            plt.annotate(line_eq, (5,15), fontsize=15, color="red")
        elif (hemisphere.iloc[0,0] == Southern_hemisphere.iloc[0,0]) & (condition != "Wind Speed"):
            plt.annotate(line_eq, (-50,45), fontsize=15, color="red")
        else:
            plt.annotate(line_eq, (-50,5), fontsize=15, color="red")
            
        plt.show()
        
        print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.6723594168263014.
# The r-squared is: 0.02772738117335638.
# The r-squared is: 0.00015902527610810567.
# The r-squared is: 0.0005686355798524872.
# The r-squared is: 0.5948710765849687.
# The r-squared is: 0.02942703912368484.
# The r-squared is: 0.03110544894683915.
# The r-squared is: 0.015325851772742507.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Northern_hemisphere.plot(kind="scatter", x="Lat", y="Max Temp",
                         title = f"Northern Hemisphere City Latitude vs. Max Temperature {date_string}",
                            edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Northern_hemisphere["Lat"], Northern_hemisphere["Max Temp"])
regress_values = Northern_hemisphere["Lat"]*slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(Northern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (5,30), fontsize=15, color="red")

plt.savefig("../static/images/northHemisphereTemperature.png")

plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.6723594168263014.

# %% [markdown]
# Here cities in the northern hemisphere have their maximum temperatures charted against their latitude. The trend shows that the farther from the equator a city is the lower its maximum temperature

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Southern_hemisphere.plot(kind="scatter", x="Lat", y="Max Temp",
                         title = f"Southern Hemisphere City Latitude vs. Max Temperature {date_string}",
                            edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Southern_hemisphere["Lat"], Southern_hemisphere["Max Temp"])
regress_values = Southern_hemisphere["Lat"]*slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(Southern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (-50,40), fontsize=15, color="red")

plt.savefig("../static/images/southHemisphereTemperature.png")

plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.5948710765849687.

# %% [markdown]
# Here cities in the southern hemisphere have their maximum temperature charted against their latitude. The trend shows higher maximum temperatures closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Northern_hemisphere.plot(kind="scatter", x="Lat", y="Humidity",
                         title = f"Northern Hemisphere City Latitude vs. Humidity {date_string}",
                            edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Northern_hemisphere["Lat"], Northern_hemisphere["Humidity"])
regress_values = Northern_hemisphere["Lat"]*slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(Northern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (8,48), fontsize=15, color="red")

plt.savefig("../static/images/northHemisphereHumidity.png")

plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.02772738117335638.

# %% [markdown]
# Here cities in the northern hemisphere have their humidity charted against their latitude. There doesn't seem to be a strong trend between humidity and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Southern_hemisphere.plot(kind="scatter", x="Lat", y="Humidity",
                         title = f"Southern Hemisphere City Latitude vs. Humidity {date_string}",
                            edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Southern_hemisphere["Lat"], Southern_hemisphere["Humidity"])
regress_values = Southern_hemisphere["Lat"]*slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(Southern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (-56,51), fontsize=15, color="red")

plt.savefig("../static/images/southHemisphereHumidity.png")

plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.02942703912368484.

# %% [markdown]
# Here cities in the southern hemisphere have their humidity charted against their latitude. There doesn't seem to be a strong trend between latitude and humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Northern_hemisphere.plot(kind="scatter", x="Lat", y="Cloudiness",
                         title = f"Northern Hemisphere City Latitude vs. Cloudiness {date_string}",
                            edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Northern_hemisphere["Lat"], Northern_hemisphere["Cloudiness"])
regress_values = Northern_hemisphere["Lat"]*slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(Northern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (2,60), fontsize=15, color="red")

plt.savefig("../static/images/northHemisphereCloudiness.png")

plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.00015902527610810567.

# %% [markdown]
# Here cities in the northern hemisphere have their cloud coverage plotted against their latitude. There seems to be horizontal groupings of data along easily chosen estimates for cloud coverage.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Southern_hemisphere.plot(kind="scatter", x="Lat", y="Cloudiness",
                         title = f"Southern Hemisphere City Latitude vs. Cloudiness {date_string}",
                            edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Southern_hemisphere["Lat"], Southern_hemisphere["Cloudiness"])
regress_values = Southern_hemisphere["Lat"]*slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(Southern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (-48,43), fontsize=15, color="red")

plt.savefig("../static/images/southHemisphereCloudiness.png")

plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.03110544894683915.

# %% [markdown]
# Here cities in the southern hemisphere have their cloud coverage plotted against their latitude. There doesn't seem to be a strong correlation between cloudiness and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Northern_hemisphere.plot(kind="scatter", x="Lat", y="Wind Speed",
                         title = f"Northern Hemisphere City Latitude vs. Wind Speed {date_string}",
                            edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Northern_hemisphere["Lat"], Northern_hemisphere["Wind Speed"])
regress_values = Northern_hemisphere["Lat"]*slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(Northern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (2,25), fontsize=15, color="red")

plt.savefig("../static/images/northHemisphereWindSpeed.png")

plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.0005686355798524872.

# %% [markdown]
# Here cities in the northern hemisphere have their wind speed charted against their latitude. There seems to be higher wind speeds farther from the equator.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Southern_hemisphere.plot(kind="scatter", x="Lat", y="Wind Speed",
                         title = f"Southern Hemisphere City Latitude vs. Wind Speed {date_string}",
                            edgecolor="black", s=40, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Southern_hemisphere["Lat"], Southern_hemisphere["Wind Speed"])
regress_values = Southern_hemisphere["Lat"]*slope + intercept
line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(Southern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (-26,10), fontsize=15, color="red")

plt.savefig("../static/images/southHemisphereWindSpeed.png")

plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.015325851772742507.

# %% [markdown]
# Here cities in the southern hemisphere have their wind speed plotted against their latitude. There seems to be higher wind speeds farther from the equator.
